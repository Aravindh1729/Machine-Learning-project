# %% [markdown]
# Dataset contains information about train booking.
# There are 215909 datapoints and 10 features in the cleaned dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Read csv file

# %%
df=pd.read_csv("train_data.csv")

# %%
df
# Out:
#         Unnamed: 0          insert_date      origin destination  \
# 0              702  2019-04-19 05:37:35  PONFERRADA      MADRID
# 1              703  2019-04-19 05:37:35  PONFERRADA      MADRID
# 2              704  2019-04-19 05:37:35  PONFERRADA      MADRID
# 3              705  2019-04-19 05:37:35  PONFERRADA      MADRID
# 4              706  2019-04-19 05:37:35  PONFERRADA      MADRID
# ...            ...                  ...         ...         ...
# 215904     2579717  2019-04-19 05:31:30      MADRID     SEVILLA
# 215905     2579718  2019-04-19 05:31:30      MADRID     SEVILLA
# 215906     2579719  2019-04-19 05:31:30      MADRID     SEVILLA
# 215907     2579720  2019-04-19 05:31:30      MADRID     SEVILLA
# 215908     2579721  2019-04-19 05:31:30      MADRID     SEVILLA
#
#                  start_date             end_date train_type  price  \
# 0       2019-06-02 15:00:00  2019-06-02 19:42:00     MD-AVE  59.50
# ...

# %% [markdown]
# Number of rows and columns in dataset

# %%
df.shape
# Out:
# (215909, 10)

# %% [markdown]
# Column headings

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'insert_date', 'origin', 'destination', 'start_date',
#        'end_date', 'train_type', 'price', 'train_class', 'fare'],
#       dtype='object')

# %% [markdown]
# Columns with corresponding datatypes

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# insert_date     object
# origin          object
# destination     object
# start_date      object
# end_date        object
# train_type      object
# price          float64
# train_class     object
# fare            object
# dtype: object

# %% [markdown]
# Showing information of all columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215909 entries, 0 to 215908
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   215909 non-null  int64
#  1   insert_date  215909 non-null  object
#  2   origin       215909 non-null  object
#  3   destination  215909 non-null  object
#  4   start_date   215909 non-null  object
#  5   end_date     215909 non-null  object
#  6   train_type   215909 non-null  object
#  7   price        202321 non-null  float64
#  8   train_class  215266 non-null  object
#  9   fare         215266 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 16.5+ MB

# %% [markdown]
# Checking null values of each column

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# insert_date        0
# origin             0
# destination        0
# start_date         0
# end_date           0
# train_type         0
# price          13588
# train_class      643
# fare             643
# dtype: int64

# %% [markdown]
# Droping null values

# %%
df.dropna(how='any',inplace=True)
df.isnull().sum()
# Out:
# Unnamed: 0     0
# insert_date    0
# origin         0
# destination    0
# start_date     0
# end_date       0
# train_type     0
# price          0
# train_class    0
# fare           0
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False)
plt.show()

# %% [markdown]
# Combining column to create a new column

# %%
df["Route"] = df.origin + '-' + df.destination

# %%
df.shape
# Out:
# (202321, 11)

# %% [markdown]
# Droping unwanted features

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (202321, 10)

# %% [markdown]
# Converting column names to upper case

# %%
df.columns=df.columns.str.upper()

# %%
df.columns
# Out:
# Index(['INSERT_DATE', 'ORIGIN', 'DESTINATION', 'START_DATE', 'END_DATE',
#        'TRAIN_TYPE', 'PRICE', 'TRAIN_CLASS', 'FARE', 'ROUTE'],
#       dtype='object')

# %% [markdown]
# Getting first five rows

# %%
df.head()
# Out:
#            INSERT_DATE      ORIGIN DESTINATION           START_DATE  \
# 0  2019-04-19 05:37:35  PONFERRADA      MADRID  2019-06-02 15:00:00
# 1  2019-04-19 05:37:35  PONFERRADA      MADRID  2019-06-02 17:15:00
# 2  2019-04-19 05:37:35  PONFERRADA      MADRID  2019-06-02 17:15:00
# 3  2019-04-19 05:37:35  PONFERRADA      MADRID  2019-06-02 17:15:00
# 4  2019-04-19 05:37:35  PONFERRADA      MADRID  2019-06-02 18:55:00
#
#               END_DATE TRAIN_TYPE  PRICE         TRAIN_CLASS      FARE  \
# 0  2019-06-02 19:42:00     MD-AVE  59.50  Turista con enlace  Flexible
# 1  2019-06-02 23:03:00     MD-AVE  34.65  Turista con enlace   Promo +
# 2  2019-06-02 23:10:00      MD-LD  39.95  Turista con enlace   Promo +
# 3  2019-06-02 22:14:00     MD-AVE  40.60  Turista con enlace   Promo +
# 4  2019-06-02 23:03:00      ALVIA  27.90             Turista     Promo
#
#                ROUTE
# 0  PONFERRADA-MADRID
# 1  PONFERRADA-MADRID
# 2  PONFERRADA-MADRID
# 3  PONFERRADA-MADRID
# ...

# %% [markdown]
# Getting last five rows

# %%
df.tail()
# Out:
#                 INSERT_DATE  ORIGIN DESTINATION           START_DATE  \
# 215904  2019-04-19 05:31:30  MADRID     SEVILLA  2019-06-01 17:00:00
# 215905  2019-04-19 05:31:30  MADRID     SEVILLA  2019-06-01 18:00:00
# 215906  2019-04-19 05:31:30  MADRID     SEVILLA  2019-06-01 19:00:00
# 215907  2019-04-19 05:31:30  MADRID     SEVILLA  2019-06-01 20:35:00
# 215908  2019-04-19 05:31:30  MADRID     SEVILLA  2019-06-01 21:25:00
#
#                    END_DATE TRAIN_TYPE  PRICE   TRAIN_CLASS   FARE  \
# 215904  2019-06-01 19:38:00        AVE   47.3       Turista  Promo
# 215905  2019-06-01 20:32:00        AVE   47.3       Turista  Promo
# 215906  2019-06-01 21:38:00        AVE   47.3       Turista  Promo
# 215907  2019-06-01 23:15:00        AVE   47.3       Turista  Promo
# 215908  2019-06-02 00:10:00    AV City   52.2  Turista Plus  Promo
#
#                  ROUTE
# 215904  MADRID-SEVILLA
# 215905  MADRID-SEVILLA
# 215906  MADRID-SEVILLA
# 215907  MADRID-SEVILLA
# 215908  MADRID-SEVILLA

# %% [markdown]
# Treating outliers

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df['PRICE'])
plt.show()

# %% [markdown]
# Box plot is used to analyze the outliers in the dependent variable 'PRICE'. Upon observation, it becomes evident that there are outliers present in the data

# %%
df=df[~(df['PRICE']>50)]#using boolean mask to filter the price which is not greater than 50

# %%
df.shape
# Out:
# (94860, 10)

# %% [markdown]
# Removing outliers

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df['PRICE'])
plt.show()

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# Analysing values in each column

# %%
df.TRAIN_TYPE.value_counts()
# Out:
# REGIONAL     52155
# AVE          26037
# R. EXPRES     6245
# INTERCITY     2801
# AV City       2170
# ALVIA         1075
# MD-LD         1037
# TRENHOTEL      866
# MD-AVE         822
# LD             421
# AVE-LD         417
# AVE-MD         401
# LD-MD          226
# AVE-TGV        187
# Name: TRAIN_TYPE, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.countplot(df['TRAIN_TYPE'],palette='hls')
plt.title('TRAIN Count',fontsize=15)
plt.xlabel('TRAIN_TYPE')
plt.ylabel('COUNT')
plt.show()

# %% [markdown]
# Regional becomes the most popular train type among the others

# %%
df.TRAIN_CLASS.value_counts()
# Out:
# Turista               88795
# Turista con enlace     3324
# Turista Plus           1417
# Preferente             1324
# Name: TRAIN_CLASS, dtype: int64

# %%
plt.figure(figsize=(8,6))
df['TRAIN_CLASS'].value_counts().plot(kind='pie',textprops={'color':'black'},autopct='%.2f',cmap='cool')
plt.title('Classes offered by Different Trains',fontsize=15)
plt.legend(['Turista','Turista con enlace','Turista Plus','Preferente'])
plt.show()

# %% [markdown]
# Turista is the most common class among the trains

# %%
df.ORIGIN.value_counts()
# Out:
# MADRID        48552
# VALENCIA      32397
# SEVILLA        6768
# BARCELONA      5063
# PONFERRADA     2080
# Name: ORIGIN, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(df['ORIGIN'],palette='hls')
plt.title('Frequency of Origin',fontsize=15)
plt.xlabel('ORIGIN')
plt.ylabel('COUNT')
plt.show()

# %% [markdown]
# Madrid has the high frequency of origin

# %%
df.ROUTE.value_counts()
# Out:
# MADRID-VALENCIA      35565
# VALENCIA-MADRID      32397
# MADRID-SEVILLA        7219
# SEVILLA-MADRID        6768
# BARCELONA-MADRID      5063
# MADRID-BARCELONA      3789
# PONFERRADA-MADRID     2080
# MADRID-PONFERRADA     1979
# Name: ROUTE, dtype: int64

# %%
plt.figure(figsize=(24,5))
sns.countplot(df['ROUTE'],palette='hls')
plt.title('FREQUENCY OF ROUTE',fontsize=15)
plt.xlabel('ROUTE')
plt.ylabel('COUNT')
plt.show()

# %%
df.FARE.value_counts()
# Out:
# Adulto ida    58400
# Promo         32822
# Promo +        2772
# Flexible        866
# Name: FARE, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(df['FARE'],palette='hls')
plt.title('FARE',fontsize=15)
plt.xlabel('FARE')
plt.ylabel('COUNT')
plt.show()

# %%
df.DESTINATION.value_counts()
# Out:
# MADRID        46308
# VALENCIA      35565
# SEVILLA        7219
# BARCELONA      3789
# PONFERRADA     1979
# Name: DESTINATION, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(df['DESTINATION'],palette='hls')
plt.title('DESTINATION',fontsize=15)
plt.xlabel('DESTINATION')
plt.ylabel('COUNT')
plt.show()

# %%
df.groupby("TRAIN_CLASS")["PRICE"].describe()
# Out:
#                       count       mean        std    min    25%    50%    75%  \
# TRAIN_CLASS
# Preferente           1324.0  40.009970   5.323076  36.15  36.15  36.15  46.80
# Turista             88795.0  33.051057   7.580498  16.60  28.35  28.35  41.20
# Turista Plus         1417.0  38.990014  10.195193  20.60  30.90  38.80  49.15
# Turista con enlace   3324.0  37.288102   4.022978  28.10  34.35  37.45  39.95
#
#                       max
# TRAIN_CLASS
# Preferente          48.85
# Turista             49.55
# Turista Plus        49.15
# Turista con enlace  44.70

# %%
fig, axs = plt.subplots(1, 2, figsize=(24, 6))
sns.boxplot(data=df.sort_values('PRICE',ascending=False), x='TRAIN_TYPE', y='PRICE', ax=axs[0])
axs[0].set_xlabel('TRAIN_TYPE')
axs[0].set_ylabel('Price')
axs[0].set_title('Price Variation in Different Trains')
axs[0].tick_params(axis='x', rotation=45)
sns.boxplot(data=df.sort_values('PRICE',ascending=False), x='TRAIN_TYPE', y='PRICE', showfliers=False, ax=axs[1])
axs[1].set_xlabel('TRAIN_TYPE')
axs[1].set_ylabel('Price')
axs[1].set_title('Price Variation in Different Trains (Outliers Excluded)')
axs[1].tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.show()

# %%
df.groupby("DESTINATION")["PRICE"].describe()
# Out:
#                count       mean       std   min    25%    50%    75%    max
# DESTINATION
# BARCELONA     3789.0  43.935545  3.545624  32.3  43.25  43.25  43.25  49.55
# MADRID       46308.0  33.310523  7.793965  16.6  28.35  28.35  41.20  49.55
# PONFERRADA    1979.0  40.084992  4.437751  31.2  37.45  39.05  42.75  45.80
# SEVILLA       7219.0  41.892257  7.050398  22.9  38.55  43.55  47.30  49.15
# VALENCIA     35565.0  30.259311  4.931625  16.6  28.35  28.35  28.35  46.80

# %%
Preferente_df = df[df['TRAIN_CLASS'] == 'Preferente']

# %%
graph = sns.FacetGrid(Preferente_df, col="TRAIN_CLASS", height=5)
graph.map(sns.lineplot, 'ORIGIN', 'PRICE', color='purple', label='Departure Time')
graph.map(sns.lineplot, 'DESTINATION', 'PRICE', color='green', label='Arrival Time')
graph.set_axis_labels("Start Dates/End Dates", "Ticket Price")
graph.add_legend()
graph.set_titles("Price Trend for Economy Class")
plt.show()

# %%
route_prices = df.groupby('ROUTE')['PRICE'].mean().reset_index()
route_prices
# Out:
#                ROUTE      PRICE
# 0   BARCELONA-MADRID  44.549174
# 1   MADRID-BARCELONA  43.935545
# 2  MADRID-PONFERRADA  40.084992
# 3     MADRID-SEVILLA  41.892257
# 4    MADRID-VALENCIA  30.259311
# 5  PONFERRADA-MADRID  38.596947
# 6     SEVILLA-MADRID  40.144186
# 7    VALENCIA-MADRID  29.787133

# %%
sns.barplot(data=route_prices, x='ROUTE', y='PRICE')
plt.xticks(rotation=90)
plt.title("Average Price Variation by Route")
plt.xlabel("Route")
plt.ylabel("Average Price")
plt.xticks(rotation=90)
plt.show()

# %%
route_class_prices = df.groupby(['ROUTE','TRAIN_CLASS'])['PRICE'].mean().reset_index()
route_class_prices
# Out:
#                 ROUTE         TRAIN_CLASS      PRICE
# 0    BARCELONA-MADRID             Turista  44.337461
# 1    BARCELONA-MADRID        Turista Plus  46.693297
# 2    MADRID-BARCELONA             Turista  43.641923
# 3    MADRID-BARCELONA        Turista Plus  47.054601
# 4   MADRID-PONFERRADA             Turista  42.057297
# 5   MADRID-PONFERRADA  Turista con enlace  38.907022
# 6      MADRID-SEVILLA          Preferente  43.262719
# 7      MADRID-SEVILLA             Turista  42.071106
# 8      MADRID-SEVILLA  Turista con enlace  34.350000
# 9     MADRID-VALENCIA          Preferente  38.477121
# 10    MADRID-VALENCIA             Turista  30.128209
# 11    MADRID-VALENCIA        Turista Plus  33.403472
# 12  PONFERRADA-MADRID             Turista  38.198465
# 13  PONFERRADA-MADRID  Turista con enlace  38.870681
# 14     SEVILLA-MADRID          Preferente  48.736628
# 15     SEVILLA-MADRID             Turista  40.232559
# 16     SEVILLA-MADRID  Turista con enlace  34.350000
# ...

# %%
route_class_prices = df.groupby(['ROUTE', 'TRAIN_CLASS'])['PRICE'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(data=route_class_prices, x='ROUTE', y='PRICE', hue='TRAIN_CLASS')
plt.xticks(rotation=90)
plt.title("Average Ticket Price by Route on the basis Class")
plt.xlabel("Route")
plt.ylabel("Average Price")
plt.legend(title="Class")
plt.show()

# %%
average_price_by_Source = df.groupby('ORIGIN')['PRICE'].mean().reset_index()
average_price_by_Source
# Out:
#        ORIGIN      PRICE
# 0   BARCELONA  44.549174
# 1      MADRID  33.456759
# 2  PONFERRADA  38.596947
# 3     SEVILLA  40.144186
# 4    VALENCIA  29.787133

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))
df.groupby('DESTINATION').mean()['PRICE'].plot(kind='bar', color='hotpink', ax=axs[0])
axs[0].set_xlabel('Destination')
axs[0].set_ylabel('Average Price')
axs[0].set_xticklabels(axs[0].get_xticklabels(), rotation=45)
axs[0].set_title('Average Price by Destination')
df.groupby('ORIGIN').mean()['PRICE'].plot(kind='bar', color='deeppink', ax=axs[1])
axs[1].set_xlabel('ORIGIN')
axs[1].set_ylabel('Average Price')
axs[1].set_xticklabels(axs[1].get_xticklabels(), rotation=45)
axs[1].set_title('Average Price by ORIGIN')
plt.tight_layout()
plt.show()

# %%
df_pivot=df.copy()

# %%
economy_df = df[df['TRAIN_CLASS'] == 'Preferente']
df_pivot = pd.pivot_table(economy_df, index='TRAIN_TYPE', values='TRAIN_CLASS', aggfunc='count')
df_pivot.columns = ['Train Count']
df_pivot
# Out:
#             Train Count
# TRAIN_TYPE
# AVE                1324

# %%
economy_df = df[df['TRAIN_CLASS'] == 'Turista']
df_pivot = pd.pivot_table(economy_df, index='TRAIN_TYPE', values='TRAIN_CLASS', aggfunc='count')
df_pivot.columns = ['Train Count']
df_pivot
# Out:
#             Train Count
# TRAIN_TYPE
# ALVIA              1075
# AV City            2170
# AVE               23932
# AVE-TGV             187
# INTERCITY          2165
# R. EXPRES          6245
# REGIONAL          52155
# TRENHOTEL           866

# %%
economy_df = df[df['TRAIN_CLASS'] == 'Turista Plus']
df_pivot = pd.pivot_table(economy_df, index='TRAIN_TYPE', values='TRAIN_CLASS', aggfunc='count')
df_pivot.columns = ['Train Count']
df_pivot
# Out:
#             Train Count
# TRAIN_TYPE
# AVE                 781
# INTERCITY           636

# %%
economy_df = df[df['TRAIN_CLASS'] == 'Turista con enlace']
df_pivot = pd.pivot_table(economy_df, index='TRAIN_TYPE', values='TRAIN_CLASS', aggfunc='count')
df_pivot.columns = ['Train Count']
df_pivot
# Out:
#             Train Count
# TRAIN_TYPE
# AVE-LD              417
# AVE-MD              401
# LD                  421
# LD-MD               226
# MD-AVE              822
# MD-LD              1037

# %%
plt.figure(figsize = (15,10))
sns.countplot(data = df, x = "TRAIN_TYPE" ,hue = "TRAIN_CLASS")
plt.show()

# %%
df_analysis = df.groupby(['ORIGIN', 'TRAIN_TYPE']).size().reset_index(name='Count')
df_analysis
# Out:
#         ORIGIN TRAIN_TYPE  Count
# 0    BARCELONA        AVE   1215
# 1    BARCELONA    AVE-TGV    187
# 2    BARCELONA  R. EXPRES   3661
# 3       MADRID      ALVIA    359
# 4       MADRID    AV City   1370
# 5       MADRID        AVE  14417
# 6       MADRID     AVE-LD    417
# 7       MADRID     AVE-MD    401
# 8       MADRID  INTERCITY   1315
# 9       MADRID         LD    421
# 10      MADRID      MD-LD    220
# 11      MADRID  R. EXPRES   2584
# 12      MADRID   REGIONAL  26618
# 13      MADRID  TRENHOTEL    430
# 14  PONFERRADA      ALVIA    411
# 15  PONFERRADA     MD-AVE    822
# 16  PONFERRADA      MD-LD    411
# 17  PONFERRADA  TRENHOTEL    436
# 18     SEVILLA      ALVIA    305
# 19     SEVILLA    AV City    800
# 20     SEVILLA        AVE   5437
# 21     SEVILLA      LD-MD    226
# 22    VALENCIA        AVE   4968
# 23    VALENCIA  INTERCITY   1486
# 24    VALENCIA      MD-LD    406
# 25    VALENCIA   REGIONAL  25537

# %%
df_analysis1 = df.groupby(['DESTINATION', 'TRAIN_TYPE']).size().reset_index(name='Count')
df_analysis1
# Out:
#    DESTINATION TRAIN_TYPE  Count
# 0    BARCELONA        AVE   1205
# 1    BARCELONA  R. EXPRES   2584
# 2       MADRID      ALVIA    716
# 3       MADRID    AV City    800
# 4       MADRID        AVE  11620
# 5       MADRID    AVE-TGV    187
# 6       MADRID  INTERCITY   1486
# 7       MADRID      LD-MD    226
# 8       MADRID     MD-AVE    822
# 9       MADRID      MD-LD    817
# 10      MADRID  R. EXPRES   3661
# 11      MADRID   REGIONAL  25537
# 12      MADRID  TRENHOTEL    436
# 13  PONFERRADA      ALVIA    310
# 14  PONFERRADA     AVE-LD    417
# 15  PONFERRADA     AVE-MD    401
# 16  PONFERRADA         LD    421
# 17  PONFERRADA  TRENHOTEL    430
# 18     SEVILLA      ALVIA     49
# 19     SEVILLA    AV City   1370
# 20     SEVILLA        AVE   5580
# 21     SEVILLA      MD-LD    220
# 22    VALENCIA        AVE   7632
# 23    VALENCIA  INTERCITY   1315
# 24    VALENCIA   REGIONAL  26618

# %%
grouped_data1 = df.groupby(['DESTINATION', 'TRAIN_TYPE']).size().unstack()
grouped_data1.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Destination')
plt.ylabel('Count')
plt.title('Count of Trains based on Source City')
plt.xticks(rotation=45)
plt.legend(title='Trains')
plt.show()

# %% [markdown]
# Converting all catagoric values to numerical values

# %%
from sklearn.preprocessing import LabelEncoder
columns_to_encode = ['TRAIN_TYPE', 'ORIGIN','DESTINATION','TRAIN_CLASS']
le = LabelEncoder()#handling catagorical values
for column in columns_to_encode:
    df[column] = le.fit_transform(df[column])

# %% [markdown]
# Taking values for x and y. x represents the features or independent variables of the dataset. y represents the target variable or dependent variable

# %%
x=df.drop(['PRICE','ROUTE','INSERT_DATE','FARE'],axis=1)
y=df['PRICE']

# %% [markdown]
# Importing train test split

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Spliting the dataset into train and test

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %% [markdown]
# Checking for the shape of train and test for both independent and dependant variable.

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((66402, 6), (28458, 6), (66402,), (28458,))

# %% [markdown]
# Importing r2 -statistical measure indicating the goodness of fit of a regression model.

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# Linear regression

# %%
from sklearn.linear_model import LinearRegression    # shows linear relationship between a dependent (y) and one or more independent (y) variables

# %% [markdown]
# Creation of linear regresssion

# %%
modelmlr = LinearRegression()

# %% [markdown]
# Training the model

# %%
modelmlr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Prediction on test data

# %%
y_pred = modelmlr.predict(x_test)

# %% [markdown]
# Computing the scores

# %%
scoretrain = round(modelmlr.score(x_train, y_train) * 100, 2)
scoretest=round(modelmlr.score(x_test,y_test)*100,2)
r2=round(r2_score(y_test,y_pred)*100,2)

# %%
print('The score of train is',scoretrain)
print('The score of test is',scoretest)
print('The r2 score is',r2)
# Out:
# The score of train is 64.82
# The score of test is 65.36
# The r2 score is 65.36

# %% [markdown]
# DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# Creation of Decision tree regressor model

# %%
modeldcr = DecisionTreeRegressor()

# %%
modeldcr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = modeldcr.predict(x_test)

# %%
scoretrain = round(modeldcr.score(x_train, y_train) * 100, 2)
scoretest=round(modeldcr.score(x_test,y_test)*100,2)
r2=round(r2_score(y_test,y_pred)*100,2)

# %%
print('The score of train is',scoretrain)
print('The score of test is',scoretest)
print('The r2 score is',r2)
# Out:
# The score of train is 96.89
# The score of test is 96.77
# The r2 score is 96.77

# %% [markdown]
#  Random Forest regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# Creation of Random Forest regressor model

# %%
modelrfr = RandomForestRegressor()

# %%
modelrfr.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# prediction based on test data

# %%
y_pred = modelrfr.predict(x_test)

# %%
scoretrain = round(modelrfr.score(x_train, y_train) * 100, 2)
scoretest=round(modelrfr.score(x_test,y_test)*100,2)
r2=round(r2_score(y_test,y_pred)*100,2)

# %%
print('The score of train is',scoretrain)
print('The score of test is',scoretest)
print('The r2 score is',r2)
# Out:
# The score of train is 96.89
# The score of test is 96.78
# The r2 score is 96.78

# %% [markdown]
# Import ExtraTreesRegressor

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
modeletr =ExtraTreesRegressor ()

# %%
modeletr.fit(x_train,y_train)
# Out:
# ExtraTreesRegressor()

# %%
y_pred=modeletr.predict(x_test)

# %%
scoretrain = round(modeletr.score(x_train, y_train) * 100, 2)
scoretest=round(modeletr.score(x_test,y_test)*100,2)
r2=round(r2_score(y_test,y_pred)*100,2)

# %%
print('The score of train is',scoretrain)
print('The score of test is',scoretest)
print('The r2 score is',r2)
# Out:
# The score of train is 96.89
# The score of test is 96.78
# The r2 score is 96.78

# %% [markdown]
# Creating a dataframe showing the model and the score

# %%
results = pd.DataFrame({'Model': [ 'Linear Regression','Decision Tree Regressor', 'Random Forest Regressor',
'Extra Trees Regressor '],'Score': [ 65.36,96.77, 96.78,96.78]})
output_df = results.sort_values(by='Score', ascending=False)
output_df = output_df.reset_index(drop=True)
output_df
# Out:
#                      Model  Score
# 0  Random Forest Regressor  96.78
# 1   Extra Trees Regressor   96.78
# 2  Decision Tree Regressor  96.77
# 3        Linear Regression  65.36

# %%
plt.figure(figsize=(5,5))
plt.bar(output_df['Model'], output_df['Score'], color='blue')
plt.xlabel('Model')
plt.ylabel('Score')
plt.title('Comparison of Model Scores')
plt.ylim(0, 100)
plt.xticks(rotation=90)
plt.show()
